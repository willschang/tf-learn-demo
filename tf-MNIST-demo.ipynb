# %%
# loss  二次代价函数

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('./', one_hot=True)


# 设置每个 batch_size
batch_size = 100
# 共需多少批次运算
batch_nums = mnist.train.num_examples // batch_size

# 定义 placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)

# 神经网络层
w1 = tf.Variable(tf.zeros([784, 10]))
b1 = tf.Variable(tf.zeros([10]))
# 更合理的 初始值设置
# w1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
# b1 = tf.Variable(tf.zeros([2000] + 0.1))
prediction = tf.nn.softmax(tf.matmul(x, w1) + b1)

# loss function
# ESM
loss = tf.reduce_mean(tf.square(y-prediction))
# CE 交叉熵
# loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=predictions))

# 梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init_op = tf.global_variables_initializer()

# 预测结果 存储在一列表中
correct_predictions = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 计算 准确率
accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))

with tf.Session() as sess:
    sess.run(init_op)
    for epoch in range(21):
        for batch in range(batch_nums):
            batch_xs, batch_ys = mnist.train.next_batch(batch)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys})
            
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels})
        print('Iter epoch {0}, Testing accuracy is {1}'.format(epoch, acc))
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# Iter epoch 0, Testing accuracy is 0.8288000226020813
# Iter epoch 1, Testing accuracy is 0.8711000084877014
# Iter epoch 2, Testing accuracy is 0.8809000253677368
# Iter epoch 3, Testing accuracy is 0.8871999979019165
# Iter epoch 4, Testing accuracy is 0.8937000036239624
# Iter epoch 5, Testing accuracy is 0.8963000178337097
# Iter epoch 6, Testing accuracy is 0.899399995803833
# Iter epoch 7, Testing accuracy is 0.9014999866485596
# Iter epoch 8, Testing accuracy is 0.9038000106811523
# Iter epoch 9, Testing accuracy is 0.9053000211715698
# Iter epoch 10, Testing accuracy is 0.906000018119812
# Iter epoch 11, Testing accuracy is 0.9068999886512756
# Iter epoch 12, Testing accuracy is 0.9077000021934509
# Iter epoch 13, Testing accuracy is 0.9093000292778015
# Iter epoch 14, Testing accuracy is 0.9097999930381775
# Iter epoch 15, Testing accuracy is 0.9111999869346619
# Iter epoch 16, Testing accuracy is 0.9108999967575073
# Iter epoch 17, Testing accuracy is 0.9117000102996826
# Iter epoch 18, Testing accuracy is 0.9121000170707703
# Iter epoch 19, Testing accuracy is 0.913100004196167
# Iter epoch 20, Testing accuracy is 0.9133999943733215

# %%
# loss 交叉熵损失函数
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('./', one_hot=True)


# 设置每个 batch_size
batch_size = 100
# 共需多少批次运算
batch_nums = mnist.train.num_examples // batch_size

# 定义 placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)

# 神经网络层
w1 = tf.Variable(tf.zeros([784, 10]))
b1 = tf.Variable(tf.zeros([10]))
# 更合理的 初始值设置
# w1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
# b1 = tf.Variable(tf.zeros([2000] + 0.1))
prediction = tf.nn.softmax(tf.matmul(x, w1) + b1)

# loss function
# ESM
# loss = tf.reduce_mean(tf.square(y-prediction))
# CE 交叉熵
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=prediction))

# 梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init_op = tf.global_variables_initializer()

# 预测结果 存储在一列表中
correct_predictions = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 计算 准确率
accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))

with tf.Session() as sess:
    sess.run(init_op)
    for epoch in range(21):
        for batch in range(batch_nums):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys})
            
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels})
        print('Iter epoch {0}, Testing accuracy is {1}'.format(epoch, acc))
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# Iter epoch 0, Testing accuracy is 0.822700023651123
# Iter epoch 1, Testing accuracy is 0.8752999901771545
# Iter epoch 2, Testing accuracy is 0.8989999890327454
# Iter epoch 3, Testing accuracy is 0.9045000076293945
# Iter epoch 4, Testing accuracy is 0.9078999757766724
# Iter epoch 5, Testing accuracy is 0.9093999862670898
# Iter epoch 6, Testing accuracy is 0.9115999937057495
# Iter epoch 7, Testing accuracy is 0.9128999710083008
# Iter epoch 8, Testing accuracy is 0.914900004863739
# Iter epoch 9, Testing accuracy is 0.9164999723434448
# Iter epoch 10, Testing accuracy is 0.9168000221252441
# Iter epoch 11, Testing accuracy is 0.9182000160217285
# Iter epoch 12, Testing accuracy is 0.9179999828338623
# Iter epoch 13, Testing accuracy is 0.9192000031471252
# Iter epoch 14, Testing accuracy is 0.9193999767303467
# Iter epoch 15, Testing accuracy is 0.9203000068664551
# Iter epoch 16, Testing accuracy is 0.9203000068664551
# Iter epoch 17, Testing accuracy is 0.920799970626831
# Iter epoch 18, Testing accuracy is 0.9207000136375427
# Iter epoch 19, Testing accuracy is 0.9214000105857849
# Iter epoch 20, Testing accuracy is 0.9214000105857849

# %%
# Dropout 
# loss 交叉熵损失函数
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('./', one_hot=True)


# 设置每个 batch_size
batch_size = 100
# 共需多少批次运算
batch_nums = mnist.train.num_examples // batch_size

# 定义 placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)

# 神经网络层
# 更合理的 初始值设置
w1 = tf.Variable(tf.truncated_normal([784, 200], stddev=0.1))
b1 = tf.Variable(tf.zeros([200]) + 0.1)
layer1 = tf.nn.tanh(tf.matmul(x, w1) + b1)
# 调用 dropout api
layer1_dropout = tf.nn.dropout(layer1, keep_prob)

# 增加 隐藏层 2
w2 = tf.Variable(tf.truncated_normal([200, 200], stddev=0.1))
b2 = tf.Variable(tf.zeros([200]) + 0.1)
layer2 = tf.nn.tanh(tf.matmul(layer1_dropout, w2) + b2)
# 调用 dropout api
layer2_dropout = tf.nn.dropout(layer2, keep_prob)


# 增加 隐藏层 3
w3 = tf.Variable(tf.truncated_normal([200, 100], stddev=0.1))
b3 = tf.Variable(tf.zeros([100]) + 0.1)
layer3 = tf.nn.tanh(tf.matmul(layer2_dropout, w3) + b3)
# 调用 dropout api
layer3_dropout = tf.nn.dropout(layer3, keep_prob)

# 输出层
w4 = tf.Variable(tf.truncated_normal([100, 10], stddev=0.1))
b4 = tf.Variable(tf.zeros([10]) + 0.1)
prediction = tf.nn.softmax(tf.matmul(layer3_dropout, w4) + b4)

# loss function
# ESM
# loss = tf.reduce_mean(tf.square(y-prediction))
# CE 交叉熵
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=prediction))

# 梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init_op = tf.global_variables_initializer()

# 预测结果 存储在一列表中
correct_predictions = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 计算 准确率
accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))

with tf.Session() as sess:
    sess.run(init_op)
    for epoch in range(21):
        for batch in range(batch_nums):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.7})
            
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels, keep_prob: 0.7})
        print('Iter epoch {0}, Testing accuracy is {1}'.format(epoch, acc))
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# Iter epoch 0, Testing accuracy is 0.8730000257492065
# Iter epoch 1, Testing accuracy is 0.8974000215530396
# Iter epoch 2, Testing accuracy is 0.9092000126838684
# Iter epoch 3, Testing accuracy is 0.9165999889373779
# Iter epoch 4, Testing accuracy is 0.9200000166893005
# Iter epoch 5, Testing accuracy is 0.9264000058174133
# Iter epoch 6, Testing accuracy is 0.9239000082015991
# Iter epoch 7, Testing accuracy is 0.9311000108718872
# Iter epoch 8, Testing accuracy is 0.9329000115394592
# Iter epoch 9, Testing accuracy is 0.9314000010490417
# Iter epoch 10, Testing accuracy is 0.9341999888420105
# Iter epoch 11, Testing accuracy is 0.9352999925613403
# Iter epoch 12, Testing accuracy is 0.9412999749183655
# Iter epoch 13, Testing accuracy is 0.9424999952316284
# Iter epoch 14, Testing accuracy is 0.9409000277519226
# Iter epoch 15, Testing accuracy is 0.9437999725341797
# Iter epoch 16, Testing accuracy is 0.9444000124931335
# Iter epoch 17, Testing accuracy is 0.945900022983551
# Iter epoch 18, Testing accuracy is 0.9459999799728394
# Iter epoch 19, Testing accuracy is 0.9452000260353088
# Iter epoch 20, Testing accuracy is 0.9448999762535095

# %%
# loss  二次代价函数

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('./', one_hot=True)


# 设置每个 batch_size
batch_size = 100
# 共需多少批次运算
batch_nums = mnist.train.num_examples // batch_size

# 定义 placeholder
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, 784])
    y = tf.placeholder(tf.float32, [None, 10])
    keep_prob = tf.placeholder(tf.float32)

# 神经网络层
w1 = tf.Variable(tf.zeros([784, 10]))
b1 = tf.Variable(tf.zeros([10]))
# 更合理的 初始值设置
# w1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
# b1 = tf.Variable(tf.zeros([2000] + 0.1))
prediction = tf.nn.softmax(tf.matmul(x, w1) + b1)

# loss function
# ESM
loss = tf.reduce_mean(tf.square(y-prediction))
# CE 交叉熵
# loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=predictions))

# 梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init_op = tf.global_variables_initializer()

# 预测结果 存储在一列表中
correct_predictions = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 计算 准确率
accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))

with tf.Session() as sess:
    sess.run(init_op)
    writer = tf.summary.FileWriter('logs/', sess.graph)
    for epoch in range(1):
        for batch in range(batch_nums):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys})
            
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels})
        print('Iter epoch {0}, Testing accuracy is {1}'.format(epoch, acc))
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# Iter epoch 0, Testing accuracy is 0.8319000005722046
