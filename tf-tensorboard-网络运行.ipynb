# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('./', one_hot=True)


# 设置每个 batch_size
batch_size = 100
# 共需多少批次运算
batch_nums = mnist.train.num_examples // batch_size

# 参数概要
def variable_summaries(var):
  """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean', mean)
    with tf.name_scope('stddev'):
      stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev', stddev)
    tf.summary.scalar('max', tf.reduce_max(var))
    tf.summary.scalar('min', tf.reduce_min(var))
    tf.summary.histogram('histogram', var)
    
# def variable_summaries(var):
#     with tf.name_scope('summaries'):
#         mean = tf.reduce_mean(var)
#         tf.summary.scalar('mean', mean)
#         with tf.name_scope('stddev'):
#             stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
#         tf.summary.scalar('stddev', stddev)
#         tf.summary.scalar('max', tf.reduce_max(var))
#         tf.summary.scalar('min', tf.reduce_min(var))
#         tf.summary.histogram('histogram', var)

# 定义 placeholder
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32, [None, 784], name='x-input')
    y = tf.placeholder(tf.float32, [None, 10], name='y-input')

with tf.name_scope('layer1'):
    # 神经网络层
    with tf.name_scope('weight1'):
        w1 = tf.Variable(tf.zeros([784, 10]), name='w1')
        variable_summaries(w1)
    with tf.name_scope('biases1'):
        b1 = tf.Variable(tf.zeros([10]), name='b1')
        variable_summaries(b1)
    # 更合理的 初始值设置
    # w1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
    # b1 = tf.Variable(tf.zeros([2000] + 0.1))
    with tf.name_scope('softmax'):
        prediction = tf.nn.softmax(tf.matmul(x, w1) + b1)

with tf.name_scope('loss'):
    # loss function
    # ESM
    loss = tf.reduce_mean(tf.square(y-prediction))
    # CE 交叉熵
    # loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=predictions))
    tf.summary.scalar('loss', loss)

with tf.name_scope('train'):
    # 梯度下降法
    train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init_op = tf.global_variables_initializer()

with tf.name_scope('accuracy'):
    with tf.name_scope('correct_predictions'):
        # 预测结果 存储在一列表中
        correct_predictions = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))
    
    with tf.name_scope('accuracy'):
        # 计算 准确率
        accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32))
        tf.summary.scalar('accuracy', accuracy)

        
# 合并所有的 summary
merged = tf.summary.merge_all()

with tf.Session() as sess:
    sess.run(init_op)
    writer = tf.summary.FileWriter('logs/', sess.graph)
    for epoch in range(50):
        for batch in range(batch_nums):
            batch_xs, batch_ys = mnist.train.next_batch(batch)
            summary, _ = sess.run([merged, train_step], feed_dict={x: batch_xs, y: batch_ys})
            
        writer.add_summary(summary, epoch)
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels})
        print('Iter epoch {0}, Testing accuracy is {1}'.format(epoch, acc))
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# Iter epoch 0, Testing accuracy is 0.8324999809265137
# Iter epoch 1, Testing accuracy is 0.8709999918937683
# Iter epoch 2, Testing accuracy is 0.8817999958992004
# Iter epoch 3, Testing accuracy is 0.8880000114440918
# Iter epoch 4, Testing accuracy is 0.8934999704360962
# Iter epoch 5, Testing accuracy is 0.8974000215530396
# Iter epoch 6, Testing accuracy is 0.9002000093460083
# Iter epoch 7, Testing accuracy is 0.902999997138977
# Iter epoch 8, Testing accuracy is 0.902899980545044
# Iter epoch 9, Testing accuracy is 0.9042999744415283
# Iter epoch 10, Testing accuracy is 0.9060999751091003
# Iter epoch 11, Testing accuracy is 0.9068999886512756
# Iter epoch 12, Testing accuracy is 0.9078999757766724
# Iter epoch 13, Testing accuracy is 0.9090999960899353
# Iter epoch 14, Testing accuracy is 0.9099000096321106
# Iter epoch 15, Testing accuracy is 0.9107999801635742
# Iter epoch 16, Testing accuracy is 0.9114999771118164
# Iter epoch 17, Testing accuracy is 0.9124000072479248
# Iter epoch 18, Testing accuracy is 0.9128000140190125
# Iter epoch 19, Testing accuracy is 0.9132000207901001
# Iter epoch 20, Testing accuracy is 0.9135000109672546
# Iter epoch 21, Testing accuracy is 0.9143999814987183
# Iter epoch 22, Testing accuracy is 0.9150000214576721
# Iter epoch 23, Testing accuracy is 0.9154000282287598
# Iter epoch 24, Testing accuracy is 0.9158999919891357
# Iter epoch 25, Testing accuracy is 0.9158999919891357
# Iter epoch 26, Testing accuracy is 0.9168000221252441
# Iter epoch 27, Testing accuracy is 0.9175000190734863
# Iter epoch 28, Testing accuracy is 0.9175999760627747
# Iter epoch 29, Testing accuracy is 0.9182999730110168
# Iter epoch 30, Testing accuracy is 0.9182999730110168
# Iter epoch 31, Testing accuracy is 0.91839998960495
# Iter epoch 32, Testing accuracy is 0.9187999963760376
# Iter epoch 33, Testing accuracy is 0.91839998960495
# Iter epoch 34, Testing accuracy is 0.91839998960495
# Iter epoch 35, Testing accuracy is 0.9180999994277954
# Iter epoch 36, Testing accuracy is 0.91839998960495
# Iter epoch 37, Testing accuracy is 0.9190999865531921
# Iter epoch 38, Testing accuracy is 0.9190999865531921
# Iter epoch 39, Testing accuracy is 0.9197999835014343
# Iter epoch 40, Testing accuracy is 0.9189000129699707
# Iter epoch 41, Testing accuracy is 0.9193000197410583
# Iter epoch 42, Testing accuracy is 0.9192000031471252
# Iter epoch 43, Testing accuracy is 0.9197999835014343
# Iter epoch 44, Testing accuracy is 0.9205999970436096
# Iter epoch 45, Testing accuracy is 0.9203000068664551
# Iter epoch 46, Testing accuracy is 0.9204999804496765
# Iter epoch 47, Testing accuracy is 0.9210000038146973
# Iter epoch 48, Testing accuracy is 0.9210000038146973
# Iter epoch 49, Testing accuracy is 0.9210000038146973
